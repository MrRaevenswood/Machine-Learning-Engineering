# %% [markdown]
# # TensorFlow Transform - EUR/USD Forex Data
#
# Using the TensorFlow Transform tutorial in Google's documentation, I loaded a EUR/USD forex data csv via pandas and then converted to the format that the preprocessing_fn expects based on the metadata.

# %%
import tensorflow as tf
import tensorflow_transform as tft

import tensorflow_transform.beam as tft_beam
from tensorflow_transform.tf_metadata import dataset_metadata
from tensorflow_transform.tf_metadata import schema_utils
import pandas as pd
from datetime import datetime

# %%
def preprocessing_fn(inputs):    
    open = inputs['Open']
    high = inputs['High']
    low = inputs['Low']
    close = inputs['Close']
    volume = inputs['Volume']
    
    scaledClose = tft.scale_to_0_1(close)
    scaledHigh = tft.scale_to_0_1(high)
    scaledLow = tft.scale_to_0_1(low)
    scaledOpen = tft.scale_to_0_1(open)
    scaledVolume = tft.scale_to_0_1(volume)
    
    return {
        "scaledOpen":scaledOpen,
        "scaledHigh":scaledHigh, 
        "scaledLow":scaledLow,
        "scaledClose":scaledClose,
        "scaledVolume":scaledVolume
    }

# %%
eurUsdDf = pd.read_csv('/Users/marae/source/repos/Machine-Learning-Engineering/MLOps Coursera/MLlifeProd/TensorFlow Data Transform Tutorial/EURUSD_D1.csv')

# %%
eurUsdDf.rename(columns={'2007-01-01 00:00':'Date','1.31908':'Open','1.32176':'High','1.3165':'Low','1.3212':'Close','1995282':'Volume'},inplace=True)
eurUsdDf['Date'] = pd.to_datetime(eurUsdDf['Date'])
eurUsdDf['Open'] = eurUsdDf['Open'].astype('float32')
eurUsdDf['High'] = eurUsdDf['High'].astype('float32')
eurUsdDf['Low'] = eurUsdDf['Low'].astype('float32')
eurUsdDf['Close'] = eurUsdDf['Close'].astype('float32')
eurUsdDf['Volume'] = eurUsdDf['Volume'].astype('float32')

# %% [markdown]
# ## Lessons Learned
#
# The below section represents the area of the assignment that I spent the most time on since, at first, it did not seem like I could use a dataframe at all to load the data to the preprocessing_fn. I tried so many different methods that at one point my import section was three times as long with probably four times more cells with scattered attempts at getting the right format for the data.
#
# The method I eventually chose was one that I was aware of, but did not take as I felt their should be a more efficient way of doing this. For the sake of the assignment here, I stuck with the following solution, but I will ask around in Stack Overflow for something better.

# %%
eurUsdDfTransformed = []
dictDf = {}
columns = eurUsdDf.columns
for index in eurUsdDf.index:
    for cols in list(np.arange(0,len(columns))):
        colIndex = eurUsdDf.columns.get_loc(columns[cols])
        if columns[cols] == "Date":
            dictDf[columns[cols]] = bytes(eurUsdDf.iloc[index,colIndex].strftime("%m/%d/%Y %H:%M:%S"),'utf-8')
        else:
            dictDf[columns[cols]] = float(eurUsdDf.iloc[index,colIndex])
    eurUsdDfTransformed.append(dictDf)
    dictDf = {}
    
RAW_DATA_FEATURE_SPEC = dict(
        [('Date',tf.io.FixedLenFeature([],tf.string))] +
        [('Open', tf.io.FixedLenFeature([], tf.float32))] +
        [('High', tf.io.FixedLenFeature([], tf.float32))] +
        [('Low', tf.io.FixedLenFeature([],tf.float32))] +
        [('Close', tf.io.FixedLenFeature([], tf.float32))] + 
        [('Volume', tf.io.FixedLenFeature([], tf.float32))]
    )


raw_data_metadata = dataset_metadata.DatasetMetadata(
    schema_utils.schema_from_feature_spec(RAW_DATA_FEATURE_SPEC))

# %%
with tft_beam.Context(temp_dir=tempfile.mkdtemp()):
    transformed_dataset, transform_fn = (  # pylint: disable=unused-variable
        (eurUsdDfTransformed, raw_data_metadata) | tft_beam.AnalyzeAndTransformDataset(
            preprocessing_fn))
# Out:
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:tensorflow:You are passing instance dicts and DatasetMetadata to TFT which will not provide optimal performance. Consider following the TFT guide to upgrade to the TFXIO format (Apache Arrow RecordBatch).
# WARNING:apache_beam.options.pipeline_options:Discarding unparseable args: ['C:\\Users\\marae\\anaconda3\\lib\\site-packages\\ipykernel_launcher.py', '-f', 'C:\\Users\\marae\\AppData\\Roaming\\jupyter\\runtime\\kernel-b8f1b7e1-8bb9-4571-9066-9effd1996b83.json']
# WARNING:root:Make sure that locally built Python SDK docker image has Python 3.8 interpreter.
# INFO:tensorflow:Assets written to: C:\Users\marae\AppData\Local\Temp\tmpyz_1wibh\tftransform_tmp\5fb0ea0df7f5439392acffa3b9ac0c4f\assets
# INFO:tensorflow:Assets written to: C:\Users\marae\AppData\Local\Temp\tmpyz_1wibh\tftransform_tmp\5fb0ea0df7f5439392acffa3b9ac0c4f\assets
# INFO:tensorflow:Assets written to: C:\Users\marae\AppData\Local\Temp\tmpyz_1wibh\tftransform_tmp\4865b783a887489281131ab9ddeea2f6\assets
# INFO:tensorflow:Assets written to: C:\Users\marae\AppData\Local\Temp\tmpyz_1wibh\tftransform_tmp\4865b783a887489281131ab9ddeea2f6\assets

# %%
transformed_data, transformed_metadata = transformed_dataset  # pylint: disable=unused-variable

print('\nRaw data:\n{}\n'.format(pprint.pformat(eurUsdDfTransformed)))
print('Transformed data:\n{}'.format(pprint.pformat(transformed_data)))
# Out:
# Raw data:
# [{'Close': 1.3212000131607056,
#   'Date': b'01/01/2007 00:00:00',
#   'High': 1.3217600584030151,
#   'Low': 1.316499948501587,
#   'Open': 1.3190799951553345,
#   'Volume': 1995282.0},
#  {'Close': 1.327239990234375,
#   'Date': b'01/02/2007 00:00:00',
#   'High': 1.329509973526001,
#   'Low': 1.3210099935531616,
#   'Open': 1.321370005607605,
#   'Volume': 2009661.0},
#  {'Close': 1.3169000148773193,
#   'Date': b'01/03/2007 00:00:00',
#   'High': 1.3290300369262695,
#   'Low': 1.3146100044250488,
#   'Open': 1.3270200490951538,
#   'Volume': 2016603.0},
#  {'Close': 1.3085999488830566,
#   'Date': b'01/04/2007 00:00:00',
#   'High': 1.317829966545105,
#   'Low': 1.3070399761199951,
#   'Open': 1.316890001296997,
#   'Volume': 2007990.0},
#  {'Close': 1.2999500036239624,
#   'Date': b'01/05/2007 00:00:00',
#   'High': 1.310289978981018,
#   'Low': 1.2980400323867798,
#   'Open': 1.3086600303649902,
#   'Volume': 1916561.0},
#  {'Close': 1.3003900051116943,
#   'Date': b'01/07/2007 00:00:00',
#   'High': 1.3014099597930908,
#   'Low': 1.3000600337982178,
#   'Open': 1.3009699583053589,
#   'Volume': 96987.0},
#  {'Close': 1.3035600185394287,
#   'Date': b'01/08/2007 00:00:00',
#   'High': 1.3038899898529053,
#   'Low': 1.29721999168396,
#   'Open': 1.3005499839782715,
#   'Volume': 2008364.0},
#  {'Close': 1.2991900444030762,
#   'Date': b'01/09/2007 00:00:00',
#   'High': 1.3051700592041016,
#   'Low': 1.298550009727478,
#   'Open': 1.3035000562667847,
#   'Volume': 2000772.0},
#  {'Close': 1.293470025062561,
#   'Date': b'01/10/2007 00:00:00',
#   'High': 1.3000199794769287,
#   'Low': 1.2926100492477417,
#   'Open': 1.2992099523544312,
#   'Volume': 2024197.0},
#  {'Close': 1.2891000509262085,
#   'Date': b'01/11/2007 00:00:00',
#   'High': 1.3012399673461914,
#   'Low': 1.288040041923523,
#   'Open': 1.2934499979019165,
#   'Volume': 2006027.0},
#  {'Close': 1.2921199798583984,
#   'Date': b'01/12/2007 00:00:00',
#   'High': 1.2941800355911255,
#   'Low': 1.286679983139038,
#   'Open': 1.2890900373458862,
#   'Volume': 1901316.0},
#  {'Close': 1.2924200296401978,
#   'Date': b'01/14/2007 00:00:00',
#   'High': 1.2927600145339966,
#   'Low': 1.2915199995040894,
#   'Open': 1.2921899557113647,
#   'Volume': 97631.0},
#  {'Close': 1.29298996925354,
#   'Date': b'01/15/2007 00:00:00',
#   'High': 1.2955000400543213,
#   'Low': 1.2912100553512573,
#   'Open': 1.2925399541854858,
#   'Volume': 1996045.0},
#  {'Close': 1.2916500568389893,
#   'Date': b'01/16/2007 00:00:00',
#   'High': 1.2987500429153442,
#   'Low': 1.290619969367981,
#   'Open': 1.2933800220489502,
#   'Volume': 2024073.0},
#  {'Close': 1.29367995262146,
#   'Date': b'01/17/2007 00:00:00',
#   'High': 1.2949399948120117,
#   'Low': 1.2897299528121948,
#   'Open': 1.2915899753570557,
#   'Volume': 1995576.0},
#  {'Close': 1.2958999872207642,
#   'Date': b'01/18/2007 00:00:00',
#   'High': 1.2975599765777588,
#   'Low': 1.2897100448608398,
#   'Open': 1.293720006942749,
#   'Volume': 1998445.0},
#  {'Close': 1.2953599691390991,
#   'Date': b'01/19/2007 00:00:00',
#   'High': 1.2999800443649292,
#   'Low': 1.291290044784546,
#   'Open': 1.2959400415420532,
#   'Volume': 1912665.0},
#  {'Close': 1.2958999872207642,
#   'Date': b'01/21/2007 00:00:00',
#   'High': 1.2963600158691406,
#   'Low': 1.295050024986267,
#   'Open': 1.2959200143814087,
#   'Volume': 95346.0},
#  {'Close': 1.294659972190857,
#   'Date': b'01/22/2007 00:00:00',
#   'High': 1.2976900339126587,
#   'Low': 1.292009949684143,
#   'Open': 1.2959699630737305,
#   'Volume': 1999587.0},
#  {'Close': 1.3020000457763672,
#   'Date': b'01/23/2007 00:00:00',
#   'High': 1.304229974746704,
#   'Low': 1.2928800582885742,
#   'Open': 1.2948600053787231,
#   'Volume': 2006444.0},
#  {'Close': 1.296090006828308,
#   'Date': b'01/24/2007 00:00:00',
#   'High': 1.303570032119751,
#   'Low': 1.2947499752044678,
#   'Open': 1.3019499778747559,
#   'Volume': 2004188.0},
#  {'Close': 1.2935700416564941,
#   'Date': b'01/25/2007 00:00:00',
#   'High': 1.3000199794769287,
#   'Low': 1.2913899421691895,
#   'Open': 1.2958999872207642,
#   'Volume': 2006928.0},
#  {'Close': 1.2914400100708008,
#   'Date': b'01/26/2007 00:00:00',
#   'High': 1.293910026550293,
#   'Low': 1.2880699634552002,
#   'Open': 1.2932900190353394,
#   'Volume': 1907088.0},
#  {'Close': 1.2919199466705322,
#   'Date': b'01/28/2007 00:00:00',
#   'High': 1.2924599647521973,
#   'Low': 1.2912800312042236,
#   'Open': 1.2914700508117676,
#   'Volume': 96284.0},
#  {'Close': 1.2960100173950195,
#   'Date': b'01/29/2007 00:00:00',
#   'High': 1.2965500354766846,
#   'Low': 1.2894799709320068,
#   'Open': 1.2921500205993652,
#   'Volume': 2008872.0},
#  {'Close': 1.2961699962615967,
#   'Date': b'01/30/2007 00:00:00',
#   'High': 1.2979999780654907,
#   'Low': 1.2943600416183472,
#   'Open': 1.2960799932479858,
#   'Volume': 1994983.0},
#  {'Close': 1.3017499446868896,
#   'Date': b'01/31/2007 00:00:00',
#   'High': 1.3035600185394287,
#   'Low': 1.292389988899231,
#   'Open': 1.2963000535964966,
#   'Volume': 2006700.0},
#  {'Close': 1.3012299537658691,
#   'Date': b'02/01/2007 00:00:00',
#   'High': 1.304819941520691,
#   'Low': 1.3001099824905396,
#   'Open': 1.302109956741333,
#   'Volume': 2001928.0},
#  {'Close': 1.2956199645996094,
#   'Date': b'02/02/2007 00:00:00',
#   'High': 1.306149959564209,
#   'Low': 1.2947399616241455,
#   'Open': 1.3013999462127686,
#   'Volume': 1915610.0},
#  {'Close': 1.2958199977874756,
#   'Date': b'02/04/2007 00:00:00',
#   'High': 1.2962100505828857,
#   'Low': 1.2949800491333008,
#   'Open': 1.2961000204086304,
#   'Volume': 94234.0},
#  {'Close': 1.2931599617004395,
#   'Date': b'02/05/2007 00:00:00',
#   'High': 1.2965099811553955,
#   'Low': 1.291260004043579,
#   'Open': 1.2959699630737305,
#   'Volume': 2007395.0},
#  {'Close': 1.2980200052261353,
#   'Date': b'02/06/2007 00:00:00',
#   'High': 1.2990399599075317,
#   'Low': 1.2909499406814575,
#   'Open': 1.2930200099945068,
#   'Volume': 1995278.0},
#  {'Close': 1.302090048789978,
#   'Date': b'02/07/2007 00:00:00',
#   'High': 1.3023200035095215,
#   'Low': 1.296470046043396,
#   'Open': 1.298200011253357,
#   'Volume': 2006533.0},
#  {'Close': 1.3034299612045288,
#   'Date': b'02/08/2007 00:00:00',
#   'High': 1.3042800426483154,
#   'Low': 1.2975900173187256,
#   'Open': 1.3020800352096558,
#   'Volume': 2013678.0},
#  {'Close': 1.300469994544983,
#   'Date': b'02/09/2007 00:00:00',
#   'High': 1.3045200109481812,
#   'Low': 1.2981699705123901,
#   'Open': 1.3035900592803955,
#   'Volume': 1917813.0},
#  {'Close': 1.301669955253601,
#   'Date': b'02/11/2007 00:00:00',
#   'High': 1.3023699522018433,
#   'Low': 1.298509955406189,
#   'Open': 1.2989000082015991,
#   'Volume': 102389.0},
#  {'Close': 1.2956000566482544,
#   'Date': b'02/12/2007 00:00:00',
#   'High': 1.3035900592803955,
#   'Low': 1.2939000129699707,
#   'Open': 1.3014700412750244,
#   'Volume': 2038670.0},
#  {'Close': 1.3029799461364746,
#   'Date': b'02/13/2007 00:00:00',
#   'High': 1.304260015487671,
#   'Low': 1.2949800491333008,
#   'Open': 1.2954599857330322,
#   'Volume': 1995205.0},
#  {'Close': 1.3136800527572632,
#   'Date': b'02/14/2007 00:00:00',
#   'High': 1.3148800134658813,
#   'Low': 1.3021800518035889,
#   'Open': 1.3026399612426758,
#   'Volume': 2007692.0},
#  {'Close': 1.313289999961853,
#   'Date': b'02/15/2007 00:00:00',
#   'High': 1.3171600103378296,
#   'Low': 1.3117300271987915,
#   'Open': 1.3134599924087524,
#   'Volume': 2013540.0},
#  {'Close': 1.3135600090026855,
#   'Date': b'02/16/2007 00:00:00',
#   'High': 1.3144299983978271,
#   'Low': 1.3095799684524536,
#   'Open': 1.3131599426269531,
#   'Volume': 1912825.0},
#  {'Close': 1.314650058746338,
#   'Date': b'02/18/2007 00:00:00',
#   'High': 1.3162100315093994,
#   'Low': 1.3133800029754639,
#   'Open': 1.3136399984359741,
#   'Volume': 96602.0},
#  {'Close': 1.3149800300598145,
#   'Date': b'02/19/2007 00:00:00',
#   'High': 1.316100001335144,
#   'Low': 1.3120100498199463,
#   'Open': 1.314620018005371,
#   'Volume': 2029773.0},
#  {'Close': 1.3145999908447266,
#   'Date': b'02/20/2007 00:00:00',
#   'High': 1.318809986114502,
#   'Low': 1.3127100467681885,
#   'Open': 1.3149199485778809,
#   'Volume': 2016429.0},
#  {'Close': 1.3136099576950073,
#   'Date': b'02/21/2007 00:00:00',
#   'High': 1.316480040550232,
#   'Low': 1.3111599683761597,
#   'Open': 1.3143399953842163,
#   'Volume': 2007520.0},
#  {'Close': 1.312119960784912,
#   'Date': b'02/22/2007 00:00:00',
#   'High': 1.314039945602417,
#   'Low': 1.307960033416748,
#   'Open': 1.313539981842041,
#   'Volume': 2003040.0},
#  {'Close': 1.3162699937820435,
#   'Date': b'02/23/2007 00:00:00',
#   'High': 1.3186299800872803,
#   'Low': 1.310130000114441,
#   'Open': 1.3122700452804565,
#   'Volume': 1919802.0},
#  {'Close': 1.3179999589920044,
#   'Date': b'02/25/2007 00:00:00',
#   'High': 1.318600058555603,
#   'Low': 1.316290020942688,
#   'Open': 1.316499948501587,
#   'Volume': 96663.0},
#  {'Close': 1.3191100358963013,
#   'Date': b'02/26/2007 00:00:00',
#   'High': 1.3197100162506104,
#   'Low': 1.3149100542068481,
#   'Open': 1.318079948425293,
#   'Volume': 2003582.0},
#  {'Close': 1.3225899934768677,
#   'Date': b'02/27/2007 00:00:00',
#   'High': 1.3257800340652466,
#   'Low': 1.315790057182312,
#   'Open': 1.3191100358963013,
#   'Volume': 2000909.0},
#  {'Close': 1.3227100372314453,
#   'Date': b'02/28/2007 00:00:00',
#   'High': 1.3236900568008423,
#   'Low': 1.317870020866394,
#   'Open': 1.3229700326919556,
#   'Volume': 1989313.0},
#  {'Close': 1.3164399862289429,
#   'Date': b'03/01/2007 00:00:00',
#   'High': 1.323889970779419,
#   'Low': 1.3154699802398682,
#   'Open': 1.3225500583648682,
#   'Volume': 2011124.0},
#  {'Close': 1.3188199996948242,
#   'Date': b'03/02/2007 00:00:00',
#   'High': 1.3199800252914429,
#   'Low': 1.314079999923706,
#   'Open': 1.3165600299835205,
#   'Volume': 1901870.0},
#  {'Close': 1.3181999921798706,
#   'Date': b'03/04/2007 00:00:00',
#   'High': 1.3210099935531616,
#   'Low': 1.3181699514389038,
#   'Open': 1.3194899559020996,
#   'Volume': 97703.0},
#  {'Close': 1.30840003490448,
#   'Date': b'03/05/2007 00:00:00',
#   'High': 1.3192600011825562,
#   'Low': 1.307229995727539,
#   'Open': 1.318019986152649,
#   'Volume': 2005429.0},
#  {'Close': 1.3133200407028198,
#   'Date': b'03/06/2007 00:00:00',
#   'High': 1.3138999938964844,
#   'Low': 1.307979941368103,
#   'Open': 1.3081300258636475,
#   'Volume': 2001070.0},
#  {'Close': 1.3174699544906616,
#   'Date': b'03/07/2007 00:00:00',
#   'High': 1.3184399604797363,
#   'Low': 1.31086003780365,
#   'Open': 1.3133800029754639,
#   'Volume': 1998425.0},
#  {'Close': 1.3136500120162964,
#   'Date': b'03/08/2007 00:00:00',
#   'High': 1.3181300163269043,
#   'Low': 1.3115400075912476,
#   'Open': 1.3173500299453735,
#   'Volume': 1995982.0},
#  {'Close': 1.3111799955368042,
#   'Date': b'03/09/2007 00:00:00',
#   'High': 1.3158299922943115,
#   'Low': 1.3086400032043457,
#   'Open': 1.3134299516677856,
#   'Volume': 1907536.0},
#  {'Close': 1.3124200105667114,
#   'Date': b'03/11/2007 00:00:00',
#   'High': 1.3141499757766724,
#   'Low': 1.3106800317764282,
#   'Open': 1.3123600482940674,
#   'Volume': 144952.0},
#  {'Close': 1.318600058555603,
#   'Date': b'03/12/2007 00:00:00',
#   'High': 1.3199199438095093,
#   'Low': 1.310539960861206,
#   'Open': 1.312209963798523,
#   'Volume': 2009176.0},
#  {'Close': 1.3186700344085693,
#   'Date': b'03/13/2007 00:00:00',
#   'High': 1.3218599557876587,
#   'Low': 1.3154699802398682,
#   'Open': 1.3185700178146362,
#   'Volume': 2004246.0},
#  {'Close': 1.3231799602508545,
#   'Date': b'03/14/2007 00:00:00',
#   'High': 1.3243999481201172,
#   'Low': 1.317639946937561,
#   'Open': 1.318560004234314,
#   'Volume': 2023927.0},
#  {'Close': 1.3278299570083618,
#   'Date': b'03/15/2007 00:00:00',
#   'High': 1.3279099464416504,
#   'Low': 1.3191900253295898,
#   'Open': 1.3232300281524658,
#   'Volume': 2005006.0},
#  {'Close': 1.3310600519180298,
#   'Date': b'03/16/2007 00:00:00',
#   'High': 1.3338099718093872,
#   'Low': 1.3272199630737305,
#   'Open': 1.3278000354766846,
#   'Volume': 1850054.0},
#  {'Close': 1.3316099643707275,
#   'Date': b'03/18/2007 00:00:00',
#   'High': 1.3319599628448486,
#   'Low': 1.3306399583816528,
#   'Open': 1.3306399583816528,
#   'Volume': 140627.0},
#  {'Close': 1.3309500217437744,
#   'Date': b'03/19/2007 00:00:00',
#   'High': 1.3324099779129028,
#   'Low': 1.3278000354766846,
#   'Open': 1.3314199447631836,
#   'Volume': 2009557.0},
#  {'Close': 1.3313499689102173,
#   'Date': b'03/20/2007 00:00:00',
#   'High': 1.332319974899292,
#   'Low': 1.3270100355148315,
#   'Open': 1.330970048904419,
#   'Volume': 2697640.0},
#  {'Close': 1.3395600318908691,
#   'Date': b'03/21/2007 00:00:00',
#   'High': 1.340939998626709,
#   'Low': 1.3286099433898926,
#   'Open': 1.3313699960708618,
#   'Volume': 2674382.0},
#  {'Close': 1.3328499794006348,
#   'Date': b'03/22/2007 00:00:00',
#   'High': 1.340019941329956,
#   'Low': 1.330899953842163,
#   'Open': 1.3395800590515137,
#   'Volume': 2670842.0},
#  {'Close': 1.3278900384902954,
#   'Date': b'03/23/2007 00:00:00',
#   'High': 1.3340699672698975,
#   'Low': 1.327620029449463,
#   'Open': 1.333109974861145,
#   'Volume': 2488815.0},
#  {'Close': 1.3270800113677979,
#   'Date': b'03/25/2007 00:00:00',
#   'High': 1.3293299674987793,
#   'Low': 1.3257100582122803,
#   'Open': 1.3280099630355835,
#   'Volume': 191699.0},
#  {'Close': 1.332669973373413,
#   'Date': b'03/26/2007 00:00:00',
#   'High': 1.3345500230789185,
#   'Low': 1.3253400325775146,
#   'Open': 1.327239990234375,
#   'Volume': 633085.0},
#  {'Close': 1.334820032119751,
#   'Date': b'03/27/2007 00:00:00',
#   'High': 1.3366700410842896,
#   'Low': 1.3301299810409546,
#   'Open': 1.3327699899673462,
#   'Volume': 614437.0},
#  {'Close': 1.3308199644088745,
#   'Date': b'03/28/2007 00:00:00',
#   'High': 1.3371599912643433,
#   'Low': 1.3300600051879883,
#   'Open': 1.3320000171661377,
#   'Volume': 625580.0},
#  {'Close': 1.3328499794006348,
#   'Date': b'03/29/2007 00:00:00',
#   'High': 1.335170030593872,
#   'Low': 1.3298399448394775,
#   'Open': 1.330839991569519,
#   'Volume': 631079.0},
#  {'Close': 1.3353500366210938,
#   'Date': b'03/30/2007 00:00:00',
#   'High': 1.3398499488830566,
#   'Low': 1.3287999629974365,
#   'Open': 1.3327699899673462,
#   'Volume': 897589.0},
#  {'Close': 1.3353999853134155,
#   'Date': b'04/01/2007 00:00:00',
#   'High': 1.3377000093460083,
#   'Low': 1.3351999521255493,
#   'Open': 1.3371000289916992,
#   'Volume': 60580.0},
#  {'Close': 1.337149977684021,
#   'Date': b'04/02/2007 00:00:00',
#   'High': 1.3380199670791626,
#   'Low': 1.3331199884414673,
#   'Open': 1.3352999687194824,
#   'Volume': 1083955.0},
#  {'Close': 1.3322499990463257,
#   'Date': b'04/03/2007 00:00:00',
#   'High': 1.3380199670791626,
#   'Low': 1.3317899703979492,
#   'Open': 1.337090015411377,
#   'Volume': 1073791.0},
#  {'Close': 1.337399959564209,
#   'Date': b'04/04/2007 00:00:00',
#   'High': 1.3380999565124512,
#   'Low': 1.3321000337600708,
#   'Open': 1.3322999477386475,
#   'Volume': 1078822.0},
#  {'Close': 1.3424500226974487,
#   'Date': b'04/05/2007 00:00:00',
#   'High': 1.344099998474121,
#   'Low': 1.3352500200271606,
#   'Open': 1.337399959564209,
#   'Volume': 943746.0},
#  {'Close': 1.3378000259399414,
#   'Date': b'04/06/2007 00:00:00',
#   'High': 1.3428000211715698,
#   'Low': 1.336400032043457,
#   'Open': 1.3424500226974487,
#   'Volume': 402447.0},
#  {'Close': 1.3367999792099,
#   'Date': b'04/08/2007 00:00:00',
#   'High': 1.337980031967163,
#   'Low': 1.3363499641418457,
#   'Open': 1.337399959564209,
#   'Volume': 30738.0},
#  {'Close': 1.3352999687194824,
#   'Date': b'04/09/2007 00:00:00',
#   'High': 1.3379000425338745,
#   'Low': 1.3339999914169312,
#   'Open': 1.3367999792099,
#   'Volume': 415233.0},
#  {'Close': 1.3428499698638916,
#   'Date': b'04/10/2007 00:00:00',
#   'High': 1.3456000089645386,
#   'Low': 1.3349000215530396,
#   'Open': 1.3352999687194824,
#   'Volume': 1221619.0},
#  {'Close': 1.3436000347137451,
#   'Date': b'04/11/2007 00:00:00',
#   'High': 1.344099998474121,
#   'Low': 1.340649962425232,
#   'Open': 1.342900037765503,
#   'Volume': 1046515.0},
#  {'Close': 1.3486000299453735,
#   'Date': b'04/12/2007 00:00:00',
#   'High': 1.3503999710083008,
#   'Low': 1.343150019645691,
#   'Open': 1.3436000347137451,
#   'Volume': 857583.0},
#  {'Close': 1.3525500297546387,
#   'Date': b'04/13/2007 00:00:00',
#   'High': 1.3552500009536743,
#   'Low': 1.3481500148773193,
#   'Open': 1.3485000133514404,
#   'Volume': 409563.0},
#  {'Close': 1.3567999601364136,
#   'Date': b'04/15/2007 00:00:00',
#   'High': 1.357699990272522,
#   'Low': 1.3522100448608398,
#   'Open': 1.3553999662399292,
#   'Volume': 39318.0},
#  {'Close': 1.3526999950408936,
#   'Date': b'04/16/2007 00:00:00',
#   'High': 1.3569999933242798,
#   'Low': 1.3522100448608398,
#   'Open': 1.356850028038025,
#   'Volume': 957423.0},
#  {'Close': 1.3571499586105347,
#   'Date': b'04/17/2007 00:00:00',
#   'High': 1.3594000339508057,
#   'Low': 1.3524999618530273,
#   'Open': 1.3526999950408936,
#   'Volume': 1048175.0},
#  {'Close': 1.361449956893921,
#   'Date': b'04/18/2007 00:00:00',
#   'High': 1.3619999885559082,
#   'Low': 1.3555999994277954,
#   'Open': 1.357200026512146,
#   'Volume': 1199617.0},
#  {'Close': 1.3624000549316406,
#   'Date': b'04/19/2007 00:00:00',
#   'High': 1.3628000020980835,
#   'Low': 1.3560500144958496,
#   'Open': 1.361449956893921,
#   'Volume': 913958.0},
#  {'Close': 1.3588000535964966,
#   'Date': b'04/20/2007 00:00:00',
#   'High': 1.363700032234192,
#   'Low': 1.3586000204086304,
#   'Open': 1.3624000549316406,
#   'Volume': 1002540.0},
#  {'Close': 1.3598999977111816,
#   'Date': b'04/22/2007 00:00:00',
#   'High': 1.360700011253357,
#   'Low': 1.3592900037765503,
#   'Open': 1.3597500324249268,
#   'Volume': 24120.0},
#  {'Close': 1.3580000400543213,
#   'Date': b'04/23/2007 00:00:00',
#   'High': 1.3602499961853027,
#   'Low': 1.3539999723434448,
#   'Open': 1.3597999811172485,
#   'Volume': 711158.0},
#  {'Close': 1.3633500337600708,
#   'Date': b'04/24/2007 00:00:00',
#   'High': 1.364300012588501,
#   'Low': 1.3547999858856201,
#   'Open': 1.3580000400543213,
#   'Volume': 1103987.0},
#  {'Close': 1.3638999462127686,
#   'Date': b'04/25/2007 00:00:00',
#   'High': 1.3665000200271606,
#   'Low': 1.3622000217437744,
#   'Open': 1.3633999824523926,
#   'Volume': 891858.0},
#  {'Close': 1.3592000007629395,
#   'Date': b'04/26/2007 00:00:00',
#   'High': 1.365399956703186,
#   'Low': 1.3583999872207642,
#   'Open': 1.3638999462127686,
#   'Volume': 1224952.0},
#  {'Close': 1.3652000427246094,
#   'Date': b'04/27/2007 00:00:00',
#   'High': 1.3681999444961548,
#   'Low': 1.3586499691009521,
#   'Open': 1.3593000173568726,
#   'Volume': 963257.0},
#  {'Close': 1.3623499870300293,
#   'Date': b'04/29/2007 00:00:00',
#   'High': 1.364799976348877,
#   'Low': 1.3615000247955322,
#   'Open': 1.3630499839782715,
#   'Volume': 41222.0},
#  {'Close': 1.3651299476623535,
#   'Date': b'04/30/2007 00:00:00',
#   'High': 1.3677699565887451,
#   'Low': 1.358839988708496,
#   'Open': 1.3623499870300293,
#   'Volume': 661518.0},
#  {'Close': 1.3602099418640137,
#   'Date': b'05/01/2007 00:00:00',
#   'High': 1.367110013961792,
#   'Low': 1.358970046043396,
#   'Open': 1.365149974822998,
#   'Volume': 663190.0},
#  {'Close': 1.3592699766159058,
#   'Date': b'05/02/2007 00:00:00',
#   'High': 1.3609700202941895,
#   'Low': 1.3559800386428833,
#   'Open': 1.360260009765625,
#   'Volume': 658266.0},
#  {'Close': 1.355080008506775,
#   'Date': b'05/03/2007 00:00:00',
#   'High': 1.361930012702942,
#   'Low': 1.3545900583267212,
#   'Open': 1.3593000173568726,
#   'Volume': 667288.0},
#  {'Close': 1.358929991722107,
#   'Date': b'05/04/2007 00:00:00',
#   'High': 1.3608800172805786,
#   'Low': 1.3534400463104248,
#   'Open': 1.3551199436187744,
#   'Volume': 607590.0},
#  {'Close': 1.3591699600219727,
#   'Date': b'05/06/2007 00:00:00',
#   'High': 1.3602299690246582,
#   'Low': 1.3588299751281738,
#   'Open': 1.3601499795913696,
#   'Volume': 56966.0},
#  {'Close': 1.359570026397705,
#   'Date': b'05/07/2007 00:00:00',
#   'High': 1.3625500202178955,
#   'Low': 1.358970046043396,
#   'Open': 1.3592000007629395,
#   'Volume': 670412.0},
#  {'Close': 1.3537700176239014,
#   'Date': b'05/08/2007 00:00:00',
#   'High': 1.3620200157165527,
#   'Low': 1.3515499830245972,
#   'Open': 1.3596199750900269,
#   'Volume': 673355.0},
#  {'Close': 1.3532600402832031,
#   'Date': b'05/09/2007 00:00:00',
#   'High': 1.356410026550293,
#   'Low': 1.3518699407577515,
#   'Open': 1.353790044784546,
#   'Volume': 659615.0},
#  {'Close': 1.3475699424743652,
#   'Date': b'05/10/2007 00:00:00',
#   'High': 1.3562400341033936,
#   'Low': 1.346560001373291,
#   'Open': 1.3532500267028809,
#   'Volume': 674149.0},
#  {'Close': 1.352220058441162,
#   'Date': b'05/11/2007 00:00:00',
#   'High': 1.3530499935150146,
#   'Low': 1.3462799787521362,
#   'Open': 1.347599983215332,
#   'Volume': 615659.0},
#  {'Close': 1.3539700508117676,
#   'Date': b'05/13/2007 00:00:00',
#   'High': 1.3543299436569214,
#   'Low': 1.3527100086212158,
#   'Open': 1.3534300327301025,
#   'Volume': 56723.0},
#  {'Close': 1.3541699647903442,
#   'Date': b'05/14/2007 00:00:00',
#   'High': 1.3557000160217285,
#   'Low': 1.3523499965667725,
#   'Open': 1.353950023651123,
#   'Volume': 666252.0},
#  {'Close': 1.3589600324630737,
#   'Date': b'05/15/2007 00:00:00',
#   'High': 1.3607100248336792,
#   'Low': 1.3526400327682495,
#   'Open': 1.354200005531311,
#   'Volume': 667555.0},
#  {'Close': 1.35207998752594,
#   'Date': b'05/16/2007 00:00:00',
#   'High': 1.3608100414276123,
#   'Low': 1.350350022315979,
#   'Open': 1.3590099811553955,
#   'Volume': 672164.0},
#  {'Close': 1.349370002746582,
#   'Date': b'05/17/2007 00:00:00',
#   'High': 1.3542100191116333,
#   'Low': 1.347730040550232,
#   'Open': 1.3521000146865845,
#   'Volume': 665765.0},
#  {'Close': 1.3505300283432007,
#   'Date': b'05/18/2007 00:00:00',
#   'High': 1.3520499467849731,
#   'Low': 1.3464800119400024,
#   'Open': 1.3494000434875488,
#   'Volume': 606693.0},
#  {'Close': 1.3519500494003296,
#   'Date': b'05/20/2007 00:00:00',
#   'High': 1.3528800010681152,
#   'Low': 1.3512300252914429,
#   'Open': 1.3512300252914429,
#   'Volume': 58641.0},
#  {'Close': 1.3461999893188477,
#   'Date': b'05/21/2007 00:00:00',
#   'High': 1.352139949798584,
#   'Low': 1.3435900211334229,
#   'Open': 1.3519500494003296,
#   'Volume': 661493.0},
#  {'Close': 1.3448699712753296,
#   'Date': b'05/22/2007 00:00:00',
#   'High': 1.3474400043487549,
#   'Low': 1.3437600135803223,
#   'Open': 1.3461500406265259,
#   'Volume': 663269.0},
#  {'Close': 1.3454099893569946,
#   'Date': b'05/23/2007 00:00:00',
#   'High': 1.3500399589538574,
#   'Low': 1.3414900302886963,
#   'Open': 1.3448699712753296,
#   'Volume': 666984.0},
#  {'Close': 1.342210054397583,
#   'Date': b'05/24/2007 00:00:00',
#   'High': 1.346019983291626,
#   'Low': 1.3415499925613403,
#   'Open': 1.3453700542449951,
#   'Volume': 670904.0},
#  {'Close': 1.3437999486923218,
#   'Date': b'05/25/2007 00:00:00',
#   'High': 1.3471399545669556,
#   'Low': 1.3411400318145752,
#   'Open': 1.3421499729156494,
#   'Volume': 422350.0},
#  {'Close': 1.344599962234497,
#   'Date': b'05/27/2007 00:00:00',
#   'High': 1.3451000452041626,
#   'Low': 1.3439899682998657,
#   'Open': 1.3446500301361084,
#   'Volume': 237012.0},
#  {'Close': 1.3450499773025513,
#   'Date': b'05/28/2007 00:00:00',
#   'High': 1.3457900285720825,
#   'Low': 1.344249963760376,
#   'Open': 1.3445600271224976,
#   'Volume': 657418.0},
#  {'Close': 1.3450700044631958,
#   'Date': b'05/29/2007 00:00:00',
#   'High': 1.351830005645752,
#   'Low': 1.341920018196106,
#   'Open': 1.3450900316238403,
#   'Volume': 663062.0},
#  {'Close': 1.3430999517440796,
#   'Date': b'05/30/2007 00:00:00',
#   'High': 1.3456300497055054,
#   'Low': 1.340790033340454,
#   'Open': 1.3451100587844849,
#   'Volume': 661363.0},
#  {'Close': 1.345229983329773,
#   'Date': b'05/31/2007 00:00:00',
#   'High': 1.347100019454956,
#   'Low': 1.3421900272369385,
#   'Open': 1.3430999517440796,
#   'Volume': 661882.0},
#  {'Close': 1.3443900346755981,
#   'Date': b'06/01/2007 00:00:00',
#   'High': 1.346019983291626,
#   'Low': 1.3391499519348145,
#   'Open': 1.3452600240707397,
#   'Volume': 422815.0},
#  {'Close': 1.3442000150680542,
#   'Date': b'06/03/2007 00:00:00',
#   'High': 1.344480037689209,
#   'Low': 1.3435300588607788,
#   'Open': 1.344099998474121,
#   'Volume': 236695.0},
#  {'Close': 1.3490699529647827,
#   'Date': b'06/04/2007 00:00:00',
#   'High': 1.3497799634933472,
#   'Low': 1.3431700468063354,
#   'Open': 1.3442200422286987,
#   'Volume': 658167.0},
#  {'Close': 1.3515700101852417,
#   'Date': b'06/05/2007 00:00:00',
#   'High': 1.3551499843597412,
#   'Low': 1.3488500118255615,
#   'Open': 1.3490899801254272,
#   'Volume': 662588.0},
#  {'Close': 1.3495700359344482,
#   'Date': b'06/06/2007 00:00:00',
#   'High': 1.3537100553512573,
#   'Low': 1.3484400510787964,
#   'Open': 1.3516199588775635,
#   'Volume': 663033.0},
#  {'Close': 1.3424700498580933,
#   'Date': b'06/07/2007 00:00:00',
#   'High': 1.3511300086975098,
#   'Low': 1.3420900106430054,
#   'Open': 1.3496299982070923,
#   'Volume': 659601.0},
#  {'Close': 1.3370800018310547,
#   'Date': b'06/08/2007 00:00:00',
#   'High': 1.3426899909973145,
#   'Low': 1.3322499990463257,
#   'Open': 1.3425099849700928,
#   'Volume': 599578.0},
#  {'Close': 1.3355900049209595,
#   'Date': b'06/10/2007 00:00:00',
#   'High': 1.3371100425720215,
#   'Low': 1.335129976272583,
#   'Open': 1.336709976196289,
#   'Volume': 56852.0},
#  {'Close': 1.3349000215530396,
#   'Date': b'06/11/2007 00:00:00',
#   'High': 1.3360600471496582,
#   'Low': 1.3332500457763672,
#   'Open': 1.335569977760315,
#   'Volume': 654360.0},
#  {'Close': 1.3300000429153442,
#   'Date': b'06/12/2007 00:00:00',
#   'High': 1.3368300199508667,
#   'Low': 1.3298100233078003,
#   'Open': 1.3349599838256836,
#   'Volume': 647328.0},
#  {'Close': 1.3307000398635864,
#   'Date': b'06/13/2007 00:00:00',
#   'High': 1.3314399719238281,
#   'Low': 1.3262100219726562,
#   'Open': 1.3299700021743774,
#   'Volume': 647149.0},
#  {'Close': 1.3308000564575195,
#   'Date': b'06/14/2007 00:00:00',
#   'High': 1.3322099447250366,
#   'Low': 1.3278900384902954,
#   'Open': 1.3306699991226196,
#   'Volume': 653285.0},
#  {'Close': 1.338670015335083,
#   'Date': b'06/15/2007 00:00:00',
#   'High': 1.3387700319290161,
#   'Low': 1.3304699659347534,
#   'Open': 1.3307700157165527,
#   'Volume': 409065.0},
#  {'Close': 1.3385499715805054,
#   'Date': b'06/17/2007 00:00:00',
#   'High': 1.3386900424957275,
#   'Low': 1.3373700380325317,
#   'Open': 1.337649941444397,
#   'Volume': 242697.0},
#  {'Close': 1.3414700031280518,
#   'Date': b'06/18/2007 00:00:00',
#   'High': 1.3417799472808838,
#   'Low': 1.3382200002670288,
#   'Open': 1.3386000394821167,
#   'Volume': 642371.0},
#  {'Close': 1.3422900438308716,
#   'Date': b'06/19/2007 00:00:00',
#   'High': 1.3434300422668457,
#   'Low': 1.3384000062942505,
#   'Open': 1.3415600061416626,
#   'Volume': 635180.0},
#  {'Close': 1.339669942855835,
#   'Date': b'06/20/2007 00:00:00',
#   'High': 1.3436000347137451,
#   'Low': 1.3389999866485596,
#   'Open': 1.342329978942871,
#   'Volume': 641082.0},
#  {'Close': 1.338879942893982,
#   'Date': b'06/21/2007 00:00:00',
#   'High': 1.340440034866333,
#   'Low': 1.3371700048446655,
#   'Open': 1.3397300243377686,
#   'Volume': 638064.0},
#  {'Close': 1.3467600345611572,
#   'Date': b'06/22/2007 00:00:00',
#   'High': 1.3468300104141235,
#   'Low': 1.3377200365066528,
#   'Open': 1.3388899564743042,
#   'Volume': 589357.0},
#  {'Close': 1.3461600542068481,
#   'Date': b'06/24/2007 00:00:00',
#   'High': 1.3468999862670898,
#   'Low': 1.3456499576568604,
#   'Open': 1.3464800119400024,
#   'Volume': 52901.0},
#  {'Close': 1.3462300300598145,
#   'Date': b'06/25/2007 00:00:00',
#   'High': 1.347190022468567,
#   'Low': 1.3438400030136108,
#   'Open': 1.3461699485778809,
#   'Volume': 625874.0},
#  {'Close': 1.3449100255966187,
#   'Date': b'06/26/2007 00:00:00',
#   'High': 1.347640037536621,
#   'Low': 1.3430999517440796,
#   'Open': 1.3461699485778809,
#   'Volume': 629894.0},
#  {'Close': 1.3453999757766724,
#   'Date': b'06/27/2007 00:00:00',
#   'High': 1.345479965209961,
#   'Low': 1.341670036315918,
#   'Open': 1.3448400497436523,
#   'Volume': 630977.0},
#  {'Close': 1.3436299562454224,
#   'Date': b'06/28/2007 00:00:00',
#   'High': 1.3478800058364868,
#   'Low': 1.342329978942871,
#   'Open': 1.3453600406646729,
#   'Volume': 630288.0},
#  {'Close': 1.3539299964904785,
#   'Date': b'06/29/2007 00:00:00',
#   'High': 1.353950023651123,
#   'Low': 1.3428399562835693,
#   'Open': 1.3435900211334229,
#   'Volume': 400958.0},
#  {'Close': 1.3534300327301025,
#   'Date': b'07/01/2007 00:00:00',
#   'High': 1.3546500205993652,
#   'Low': 1.353369951248169,
#   'Open': 1.3535799980163574,
#   'Volume': 241199.0},
#  {'Close': 1.3618700504302979,
#   'Date': b'07/02/2007 00:00:00',
#   'High': 1.3637399673461914,
#   'Low': 1.352579951286316,
#   'Open': 1.3534400463104248,
#   'Volume': 613152.0},
#  {'Close': 1.3605400323867798,
#   'Date': b'07/03/2007 00:00:00',
#   'High': 1.3632299900054932,
#   'Low': 1.3583300113677979,
#   'Open': 1.361930012702942,
#   'Volume': 605456.0},
#  {'Close': 1.361590027809143,
#   'Date': b'07/04/2007 00:00:00',
#   'High': 1.3629900217056274,
#   'Low': 1.3604400157928467,
#   'Open': 1.360610008239746,
#   'Volume': 602493.0},
#  {'Close': 1.359220027923584,
#   'Date': b'07/05/2007 00:00:00',
#   'High': 1.3657399415969849,
#   'Low': 1.3578399419784546,
#   'Open': 1.3616399765014648,
#   'Volume': 616766.0},
#  {'Close': 1.362529993057251,
#   'Date': b'07/06/2007 00:00:00',
#   'High': 1.3639600276947021,
#   'Low': 1.3567800521850586,
#   'Open': 1.3593100309371948,
#   'Volume': 566422.0},
#  {'Close': 1.3623700141906738,
#   'Date': b'07/08/2007 00:00:00',
#   'High': 1.3633699417114258,
#   'Low': 1.362149953842163,
#   'Open': 1.3631900548934937,
#   'Volume': 45764.0},
#  {'Close': 1.362030029296875,
#   'Date': b'07/09/2007 00:00:00',
#   'High': 1.3637200593948364,
#   'Low': 1.360859990119934,
#   'Open': 1.3624000549316406,
#   'Volume': 574558.0},
#  {'Close': 1.3742899894714355,
#   'Date': b'07/10/2007 00:00:00',
#   'High': 1.3782199621200562,
#   'Low': 1.3593499660491943,
#   'Open': 1.3619600534439087,
#   'Volume': 595668.0},
#  {'Close': 1.3744299411773682,
#   'Date': b'07/11/2007 00:00:00',
#   'High': 1.3779499530792236,
#   'Low': 1.3729900121688843,
#   'Open': 1.3741899728775024,
#   'Volume': 605069.0},
#  {'Close': 1.3782299757003784,
#   'Date': b'07/12/2007 00:00:00',
#   'High': 1.3797099590301514,
#   'Low': 1.3741899728775024,
#   'Open': 1.3743699789047241,
#   'Volume': 595258.0},
#  {'Close': 1.3781100511550903,
#   'Date': b'07/13/2007 00:00:00',
#   'High': 1.3810299634933472,
#   'Low': 1.3762099742889404,
#   'Open': 1.3781700134277344,
#   'Volume': 358656.0},
#  {'Close': 1.377500057220459,
#   'Date': b'07/15/2007 00:00:00',
#   'High': 1.3785500526428223,
#   'Low': 1.3767600059509277,
#   'Open': 1.3783700466156006,
#   'Volume': 237725.0},
#  {'Close': 1.37732994556427,
#   'Date': b'07/16/2007 00:00:00',
#   'High': 1.3801900148391724,
#   'Low': 1.3760299682617188,
#   'Open': 1.3774900436401367,
#   'Volume': 519815.0},
#  {'Close': 1.379349946975708,
#   'Date': b'07/17/2007 00:00:00',
#   'High': 1.3797399997711182,
#   'Low': 1.3758000135421753,
#   'Open': 1.3773399591445923,
#   'Volume': 539416.0},
#  {'Close': 1.3804500102996826,
#   'Date': b'07/18/2007 00:00:00',
#   'High': 1.3831000328063965,
#   'Low': 1.3756500482559204,
#   'Open': 1.3793200254440308,
#   'Volume': 556338.0},
#  {'Close': 1.3796800374984741,
#   'Date': b'07/19/2007 00:00:00',
#   'High': 1.3828400373458862,
#   'Low': 1.3785200119018555,
#   'Open': 1.3804399967193604,
#   'Volume': 553020.0},
#  {'Close': 1.3825099468231201,
#   'Date': b'07/20/2007 00:00:00',
#   'High': 1.384179949760437,
#   'Low': 1.377769947052002,
#   'Open': 1.3795499801635742,
#   'Volume': 777461.0},
#  {'Close': 1.3836400508880615,
#   'Date': b'07/22/2007 00:00:00',
#   'High': 1.3843799829483032,
#   'Low': 1.382680058479309,
#   'Open': 1.3833400011062622,
#   'Volume': 240416.0},
#  {'Close': 1.3798199892044067,
#   'Date': b'07/23/2007 00:00:00',
#   'High': 1.3845200538635254,
#   'Low': 1.3791199922561646,
#   'Open': 1.3835699558258057,
#   'Volume': 860850.0},
#  {'Close': 1.3819500207901,
#   'Date': b'07/24/2007 00:00:00',
#   'High': 1.3851499557495117,
#   'Low': 1.3795100450515747,
#   'Open': 1.3799699544906616,
#   'Volume': 862721.0},
#  {'Close': 1.3720300197601318,
#   'Date': b'07/25/2007 00:00:00',
#   'High': 1.3825099468231201,
#   'Low': 1.369439959526062,
#   'Open': 1.381790041923523,
#   'Volume': 859965.0},
#  {'Close': 1.3750200271606445,
#   'Date': b'07/26/2007 00:00:00',
#   'High': 1.3771400451660156,
#   'Low': 1.368880033493042,
#   'Open': 1.371999979019165,
#   'Volume': 859196.0},
#  {'Close': 1.3630599975585938,
#   'Date': b'07/27/2007 00:00:00',
#   'High': 1.3752100467681885,
#   'Low': 1.3623900413513184,
#   'Open': 1.3749899864196777,
#   'Volume': 829424.0},
#  {'Close': 1.363219976425171,
#   'Date': b'07/29/2007 00:00:00',
#   'High': 1.364150047302246,
#   'Low': 1.3605799674987793,
#   'Open': 1.3620599508285522,
#   'Volume': 33557.0},
#  {'Close': 1.3719700574874878,
#   'Date': b'07/30/2007 00:00:00',
#   'High': 1.3727400302886963,
#   'Low': 1.3617500066757202,
#   'Open': 1.3632099628448486,
#   'Volume': 861002.0},
#  {'Close': 1.3670599460601807,
#   'Date': b'07/31/2007 00:00:00',
#   'High': 1.3724000453948975,
#   'Low': 1.3663599491119385,
#   'Open': 1.3719700574874878,
#   'Volume': 863041.0},
#  {'Close': 1.366420030593872,
#   'Date': b'08/01/2007 00:00:00',
#   'High': 1.3709900379180908,
#   'Low': 1.3636300563812256,
#   'Open': 1.3671000003814697,
#   'Volume': 858940.0},
#  {'Close': 1.3702399730682373,
#   'Date': b'08/02/2007 00:00:00',
#   'High': 1.3706300258636475,
#   'Low': 1.3647799491882324,
#   'Open': 1.3662500381469727,
#   'Volume': 862289.0},
#  {'Close': 1.376979947090149,
#   'Date': b'08/03/2007 00:00:00',
#   'High': 1.3817800283432007,
#   'Low': 1.368109941482544,
#   'Open': 1.3702399730682373,
#   'Volume': 828149.0},
#  {'Close': 1.3816299438476562,
#   'Date': b'08/05/2007 00:00:00',
#   'High': 1.383870005607605,
#   'Low': 1.378600001335144,
#   'Open': 1.378600001335144,
#   'Volume': 33188.0},
#  {'Close': 1.3808000087738037,
#   'Date': b'08/06/2007 00:00:00',
#   'High': 1.3838599920272827,
#   'Low': 1.3776400089263916,
#   'Open': 1.3817600011825562,
#   'Volume': 861626.0},
#  {'Close': 1.374959945678711,
#   'Date': b'08/07/2007 00:00:00',
#   'High': 1.3813199996948242,
#   'Low': 1.3731399774551392,
#   'Open': 1.3809800148010254,
#   'Volume': 859633.0},
#  {'Close': 1.379930019378662,
#   'Date': b'08/08/2007 00:00:00',
#   'High': 1.3825900554656982,
#   'Low': 1.3718500137329102,
#   'Open': 1.3752599954605103,
#   'Volume': 861373.0},
#  {'Close': 1.3662400245666504,
#   'Date': b'08/09/2007 00:00:00',
#   'High': 1.3816699981689453,
#   'Low': 1.3653299808502197,
#   'Open': 1.3798400163650513,
#   'Volume': 860382.0},
#  {'Close': 1.369070053100586,
#   'Date': b'08/10/2007 00:00:00',
#   'High': 1.3704899549484253,
#   'Low': 1.3640600442886353,
#   'Open': 1.3665499687194824,
#   'Volume': 781855.0},
#  {'Close': 1.3689700365066528,
#   'Date': b'08/12/2007 00:00:00',
#   'High': 1.3693599700927734,
#   'Low': 1.367799997329712,
#   'Open': 1.3688700199127197,
#   'Volume': 76151.0},
#  {'Close': 1.3606899976730347,
#   'Date': b'08/13/2007 00:00:00',
#   'High': 1.3709100484848022,
#   'Low': 1.3597400188446045,
#   'Open': 1.3688299655914307,
#   'Volume': 859357.0},
#  {'Close': 1.3529499769210815,
#   'Date': b'08/14/2007 00:00:00',
#   'High': 1.3624999523162842,
#   'Low': 1.3523800373077393,
#   'Open': 1.3606200218200684,
#   'Volume': 859365.0},
#  {'Close': 1.342810034751892,
#   'Date': b'08/15/2007 00:00:00',
#   'High': 1.3531899452209473,
#   'Low': 1.3412699699401855,
#   'Open': 1.3530000448226929,
#   'Volume': 857539.0},
#  {'Close': 1.3428499698638916,
#   'Date': b'08/16/2007 00:00:00',
#   'High': 1.3446400165557861,
#   'Low': 1.3359400033950806,
#   'Open': 1.342919945716858,
#   'Volume': 857267.0},
#  {'Close': 1.3472100496292114,
#   'Date': b'08/17/2007 00:00:00',
#   'High': 1.354599952697754,
#   'Low': 1.3369100093841553,
#   'Open': 1.3424999713897705,
#   'Volume': 782475.0},
#  {'Close': 1.3470499515533447,
#   'Date': b'08/19/2007 00:00:00',
#   'High': 1.3488999605178833,
#   'Low': 1.3470499515533447,
#   'Open': 1.347599983215332,
#   'Volume': 77242.0},
#  {'Close': 1.347100019454956,
#   'Date': b'08/20/2007 00:00:00',
#   'High': 1.3507599830627441,
#   'Low': 1.345729947090149,
#   'Open': 1.3473399877548218,
#   'Volume': 856484.0},
#  {'Close': 1.3465800285339355,
#   'Date': b'08/21/2007 00:00:00',
#   'High': 1.3520300388336182,
#   'Low': 1.344849944114685,
#   'Open': 1.347100019454956,
#   'Volume': 855021.0},
#  {'Close': 1.3545600175857544,
#   'Date': b'08/22/2007 00:00:00',
#   'High': 1.3557599782943726,
#   'Low': 1.3445899486541748,
#   'Open': 1.3463499546051025,
#   'Volume': 860210.0},
#  {'Close': 1.3560999631881714,
#   'Date': b'08/23/2007 00:00:00',
#   'High': 1.3587900400161743,
#   'Low': 1.3532400131225586,
#   'Open': 1.3547699451446533,
#   'Volume': 861232.0},
#  {'Close': 1.3672499656677246,
#   'Date': b'08/24/2007 00:00:00',
#   'High': 1.368280053138733,
#   'Low': 1.3549699783325195,
#   'Open': 1.3561300039291382,
#   'Volume': 782117.0},
#  {'Close': 1.3677699565887451,
#   'Date': b'08/26/2007 00:00:00',
#   'High': 1.3681399822235107,
#   'Low': 1.3661199808120728,
#   'Open': 1.3674499988555908,
#   'Volume': 76172.0},
#  {'Close': 1.3634300231933594,
#   'Date': b'08/27/2007 00:00:00',
#   'High': 1.3685200214385986,
#   'Low': 1.363029956817627,
#   'Open': 1.3677699565887451,
#   'Volume': 859811.0},
#  {'Close': 1.3573999404907227,
#   'Date': b'08/28/2007 00:00:00',
#   'High': 1.3679900169372559,
#   'Low': 1.3569799661636353,
#   'Open': 1.3633999824523926,
#   'Volume': 854771.0},
#  {'Close': 1.366819977760315,
#   'Date': b'08/29/2007 00:00:00',
#   'High': 1.3680200576782227,
#   'Low': 1.3557000160217285,
#   'Open': 1.3575999736785889,
#   'Volume': 862073.0},
#  {'Close': 1.3667399883270264,
#   'Date': b'08/30/2007 00:00:00',
#   'High': 1.3672000169754028,
#   'Low': 1.3588299751281738,
#   'Open': 1.3667099475860596,
#   'Volume': 861255.0},
#  {'Close': 1.3627899885177612,
#   'Date': b'08/31/2007 00:00:00',
#   'High': 1.3719099760055542,
#   'Low': 1.3615800142288208,
#   'Open': 1.3666900396347046,
#   'Volume': 779424.0},
#  {'Close': 1.3630800247192383,
#   'Date': b'09/02/2007 00:00:00',
#   'High': 1.3634899854660034,
#   'Low': 1.3622299432754517,
#   'Open': 1.3627599477767944,
#   'Volume': 77003.0},
#  {'Close': 1.3610899448394775,
#   'Date': b'09/03/2007 00:00:00',
#   'High': 1.3654099702835083,
#   'Low': 1.3601700067520142,
#   'Open': 1.3629900217056274,
#   'Volume': 858983.0},
#  {'Close': 1.3622100353240967,
#   'Date': b'09/04/2007 00:00:00',
#   'High': 1.3625600337982178,
#   'Low': 1.3547999858856201,
#   'Open': 1.3609399795532227,
#   'Volume': 854567.0},
#  {'Close': 1.3650599718093872,
#   'Date': b'09/05/2007 00:00:00',
#   'High': 1.3671200275421143,
#   'Low': 1.356600046157837,
#   'Open': 1.362089991569519,
#   'Volume': 857988.0},
#  {'Close': 1.3690199851989746,
#   'Date': b'09/06/2007 00:00:00',
#   'High': 1.3709800243377686,
#   'Low': 1.3630800247192383,
#   'Open': 1.3649799823760986,
#   'Volume': 859015.0},
#  {'Close': 1.3765699863433838,
#   'Date': b'09/07/2007 00:00:00',
#   'High': 1.3797800540924072,
#   'Low': 1.3660099506378174,
#   'Open': 1.3690600395202637,
#   'Volume': 783408.0},
#  {'Close': 1.3777199983596802,
#   'Date': b'09/09/2007 00:00:00',
#   'High': 1.3785099983215332,
#   'Low': 1.3765900135040283,
#   'Open': 1.3768099546432495,
#   'Volume': 75150.0},
#  {'Close': 1.3790700435638428,
#   'Date': b'09/10/2007 00:00:00',
#   'High': 1.3814300298690796,
#   'Low': 1.3764400482177734,
#   'Open': 1.3774299621582031,
#   'Volume': 859300.0},
#  {'Close': 1.38372004032135,
#   'Date': b'09/11/2007 00:00:00',
#   'High': 1.3848199844360352,
#   'Low': 1.377560019493103,
#   'Open': 1.3790600299835205,
#   'Volume': 862697.0},
#  {'Close': 1.3892799615859985,
#   'Date': b'09/12/2007 00:00:00',
#   'High': 1.391409993171692,
#   'Low': 1.3820699453353882,
#   'Open': 1.3835200071334839,
#   'Volume': 858084.0},
#  {'Close': 1.3870999813079834,
#   'Date': b'09/13/2007 00:00:00',
#   'High': 1.3926500082015991,
#   'Low': 1.3860000371932983,
#   'Open': 1.3892300128936768,
#   'Volume': 858082.0},
#  {'Close': 1.387279987335205,
#   'Date': b'09/14/2007 00:00:00',
#   'High': 1.3894699811935425,
#   'Low': 1.3841400146484375,
#   'Open': 1.3869600296020508,
#   'Volume': 826877.0},
#  {'Close': 1.385849952697754,
#   'Date': b'09/16/2007 00:00:00',
#   'High': 1.3872699737548828,
#   'Low': 1.3852200508117676,
#   'Open': 1.3868000507354736,
#   'Volume': 33149.0},
#  {'Close': 1.386489987373352,
#   'Date': b'09/17/2007 00:00:00',
#   'High': 1.388990044593811,
#   'Low': 1.3847399950027466,
#   'Open': 1.385890007019043,
#   'Volume': 858085.0},
#  {'Close': 1.3974800109863281,
#   'Date': b'09/18/2007 00:00:00',
#   'High': 1.3988900184631348,
#   'Low': 1.3827099800109863,
#   'Open': 1.3865000009536743,
#   'Volume': 863982.0},
#  {'Close': 1.3972200155258179,
#   'Date': b'09/19/2007 00:00:00',
#   'High': 1.398669958114624,
#   'Low': 1.3932299613952637,
#   'Open': 1.3972599506378174,
#   'Volume': 861908.0},
#  {'Close': 1.4067000150680542,
#   'Date': b'09/20/2007 00:00:00',
#   'High': 1.4099299907684326,
#   'Low': 1.396589994430542,
#   'Open': 1.3971699476242065,
#   'Volume': 859798.0},
#  {'Close': 1.4088499546051025,
#   'Date': b'09/21/2007 00:00:00',
#   'High': 1.4119499921798706,
#   'Low': 1.403939962387085,
#   'Open': 1.406690001487732,
#   'Volume': 779970.0},
#  {'Close': 1.4090100526809692,
#   'Date': b'09/23/2007 00:00:00',
#   'High': 1.4093799591064453,
#   'Low': 1.4081100225448608,
#   'Open': 1.4090100526809692,
#   'Volume': 78170.0},
#  {'Close': 1.407039999961853,
#   'Date': b'09/24/2007 00:00:00',
#   'High': 1.4129300117492676,
#   'Low': 1.4065300226211548,
#   'Open': 1.4089699983596802,
#   'Volume': 858149.0},
#  {'Close': 1.4145400524139404,
#   'Date': b'09/25/2007 00:00:00',
#   'High': 1.4162800312042236,
#   'Low': 1.4056700468063354,
#   'Open': 1.407099962234497,
#   'Volume': 867085.0},
#  {'Close': 1.4126299619674683,
#   'Date': b'09/26/2007 00:00:00',
#   'High': 1.415560007095337,
#   'Low': 1.4108400344848633,
#   'Open': 1.4144999980926514,
#   'Volume': 863606.0},
#  {'Close': 1.4154399633407593,
#   'Date': b'09/27/2007 00:00:00',
#   'High': 1.4189200401306152,
#   'Low': 1.4119499921798706,
#   'Open': 1.4126800298690796,
#   'Volume': 861785.0},
#  {'Close': 1.4265600442886353,
#   'Date': b'09/28/2007 00:00:00',
#   'High': 1.4277199506759644,
#   'Low': 1.414620041847229,
#   'Open': 1.415369987487793,
#   'Volume': 829015.0},
#  {'Close': 1.4267200231552124,
#   'Date': b'09/30/2007 00:00:00',
#   'High': 1.4280799627304077,
#   'Low': 1.4260400533676147,
#   'Open': 1.4272300004959106,
#   'Volume': 32627.0},
#  {'Close': 1.4229899644851685,
#   'Date': b'10/01/2007 00:00:00',
#   'High': 1.4275100231170654,
#   'Low': 1.4207500219345093,
#   'Open': 1.4267799854278564,
#   'Volume': 861489.0},
#  {'Close': 1.4151699542999268,
#   'Date': b'10/02/2007 00:00:00',
#   'High': 1.4238899946212769,
#   'Low': 1.4135299921035767,
#   'Open': 1.4232900142669678,
#   'Volume': 864051.0},
#  {'Close': 1.4096100330352783,
#   'Date': b'10/03/2007 00:00:00',
#   'High': 1.4201200008392334,
#   'Low': 1.4079099893569946,
#   'Open': 1.415120005607605,
#   'Volume': 865666.0},
#  {'Close': 1.4134199619293213,
#   'Date': b'10/04/2007 00:00:00',
#   'High': 1.4148800373077393,
#   'Low': 1.4064099788665771,
#   'Open': 1.4094699621200562,
#   'Volume': 864452.0},
#  {'Close': 1.4133599996566772,
#   'Date': b'10/05/2007 00:00:00',
#   'High': 1.4156899452209473,
#   'Low': 1.403130054473877,
#   'Open': 1.4133599996566772,
#   'Volume': 829264.0},
#  {'Close': 1.4148099422454834,
#   'Date': b'10/07/2007 00:00:00',
#   'High': 1.4152599573135376,
#   'Low': 1.413349986076355,
#   'Open': 1.4134000539779663,
#   'Volume': 32423.0},
#  {'Close': 1.4043999910354614,
#   'Date': b'10/08/2007 00:00:00',
#   'High': 1.414870023727417,
#   'Low': 1.4032100439071655,
#   'Open': 1.414680004119873,
#   'Volume': 863957.0},
#  {'Close': 1.4104900360107422,
#   'Date': b'10/09/2007 00:00:00',
#   'High': 1.4114700555801392,
#   'Low': 1.4009300470352173,
#   'Open': 1.4043400287628174,
#   'Volume': 863733.0},
#  {'Close': 1.4137300252914429,
#   'Date': b'10/10/2007 00:00:00',
#   'High': 1.4171500205993652,
#   'Low': 1.4091399908065796,
#   'Open': 1.4106700420379639,
#   'Volume': 864978.0},
#  {'Close': 1.4197299480438232,
#   'Date': b'10/11/2007 00:00:00',
#   'High': 1.4240200519561768,
#   'Low': 1.4131799936294556,
#   'Open': 1.413699984550476,
#   'Volume': 868400.0},
#  {'Close': 1.4176299571990967,
#   'Date': b'10/12/2007 00:00:00',
#   'High': 1.4212499856948853,
#   'Low': 1.415220022201538,
#   'Open': 1.419819951057434,
#   'Volume': 788200.0},
#  {'Close': 1.4164899587631226,
#   'Date': b'10/14/2007 00:00:00',
#   'High': 1.418660044670105,
#   'Low': 1.4160900115966797,
#   'Open': 1.417449951171875,
#   'Volume': 76948.0},
#  {'Close': 1.419800043106079,
#   'Date': b'10/15/2007 00:00:00',
#   'High': 1.4242899417877197,
#   'Low': 1.4155900478363037,
#   'Open': 1.4163999557495117,
#   'Volume': 864667.0},
#  {'Close': 1.4174200296401978,
#   'Date': b'10/16/2007 00:00:00',
#   'High': 1.4226499795913696,
#   'Low': 1.4139699935913086,
#   'Open': 1.4204299449920654,
#   'Volume': 864205.0},
#  {'Close': 1.42044997215271,
#   'Date': b'10/17/2007 00:00:00',
#   'High': 1.423009991645813,
#   'Low': 1.415619969367981,
#   'Open': 1.4175100326538086,
#   'Volume': 866229.0},
#  {'Close': 1.4289300441741943,
#   'Date': b'10/18/2007 00:00:00',
#   'High': 1.4309699535369873,
#   'Low': 1.4192099571228027,
#   'Open': 1.4204000234603882,
#   'Volume': 864455.0},
#  {'Close': 1.4298499822616577,
#   'Date': b'10/19/2007 00:00:00',
#   'High': 1.4317899942398071,
#   'Low': 1.4242600202560425,
#   'Open': 1.4290499687194824,
#   'Volume': 829148.0},
#  {'Close': 1.4336400032043457,
#   'Date': b'10/21/2007 00:00:00',
#   'High': 1.4350099563598633,
#   'Low': 1.4303699731826782,
#   'Open': 1.4303699731826782,
#   'Volume': 33977.0},
#  {'Close': 1.4174699783325195,
#   'Date': b'10/22/2007 00:00:00',
#   'High': 1.4343700408935547,
#   'Low': 1.412310004234314,
#   'Open': 1.4336400032043457,
#   'Volume': 865129.0},
#  {'Close': 1.4254499673843384,
#   'Date': b'10/23/2007 00:00:00',
#   'High': 1.4278199672698975,
#   'Low': 1.4168699979782104,
#   'Open': 1.4174000024795532,
#   'Volume': 859746.0},
#  {'Close': 1.4259899854660034,
#   'Date': b'10/24/2007 00:00:00',
#   'High': 1.4269800186157227,
#   'Low': 1.4187300205230713,
#   'Open': 1.4254000186920166,
#   'Volume': 861283.0},
#  {'Close': 1.432229995727539,
#   'Date': b'10/25/2007 00:00:00',
#   'High': 1.4344300031661987,
#   'Low': 1.4243600368499756,
#   'Open': 1.4258300065994263,
#   'Volume': 861007.0},
#  {'Close': 1.439079999923706,
#   'Date': b'10/26/2007 00:00:00',
#   'High': 1.4395300149917603,
#   'Low': 1.4313700199127197,
#   'Open': 1.4322199821472168,
#   'Volume': 827554.0},
#  {'Close': 1.440209984779358,
#   'Date': b'10/28/2007 00:00:00',
#   'High': 1.4422099590301514,
#   'Low': 1.4398900270462036,
#   'Open': 1.4414600133895874,
#   'Volume': 33298.0},
#  {'Close': 1.4415299892425537,
#   'Date': b'10/29/2007 00:00:00',
#   'High': 1.4437799453735352,
#   'Low': 1.4373799562454224,
#   'Open': 1.440369963645935,
#   'Volume': 862385.0},
#  {'Close': 1.4436899423599243,
#   'Date': b'10/30/2007 00:00:00',
#   'High': 1.4442800283432007,
#   'Low': 1.4371700286865234,
#   'Open': 1.441349983215332,
#   'Volume': 861956.0},
#  {'Close': 1.4467099905014038,
#   'Date': b'10/31/2007 00:00:00',
#   'High': 1.450350046157837,
#   'Low': 1.4417200088500977,
#   'Open': 1.4437600374221802,
#   'Volume': 860167.0},
#  {'Close': 1.4422999620437622,
#   'Date': b'11/01/2007 00:00:00',
#   'High': 1.4478800296783447,
#   'Low': 1.4399499893188477,
#   'Open': 1.4468799829483032,
#   'Volume': 862822.0},
#  {'Close': 1.4503300189971924,
#   'Date': b'11/02/2007 00:00:00',
#   'High': 1.4527299404144287,
#   'Low': 1.4418400526046753,
#   'Open': 1.4423400163650513,
#   'Volume': 783393.0},
#  {'Close': 1.4502300024032593,
#   'Date': b'11/04/2007 00:00:00',
#   'High': 1.452340006828308,
#   'Low': 1.4499000310897827,
#   'Open': 1.4513200521469116,
#   'Volume': 52853.0},
#  {'Close': 1.4474999904632568,
#   'Date': b'11/05/2007 00:00:00',
#   'High': 1.450950026512146,
#   'Low': 1.44405996799469,
#   'Open': 1.4500199556350708,
#   'Volume': 860883.0},
#  {'Close': 1.4559299945831299,
#   'Date': b'11/06/2007 00:00:00',
#   'High': 1.4570599794387817,
#   'Low': 1.4465399980545044,
#   'Open': 1.4474600553512573,
#   'Volume': 860636.0},
#  {'Close': 1.462030053138733,
#   'Date': b'11/07/2007 00:00:00',
#   'High': 1.4729399681091309,
#   'Low': 1.454949975013733,
#   'Open': 1.4562300443649292,
#   'Volume': 856176.0},
#  {'Close': 1.4676200151443481,
#   'Date': b'11/08/2007 00:00:00',
#   'High': 1.470270037651062,
#   'Low': 1.461590051651001,
#   'Open': 1.4621800184249878,
#   'Volume': 859197.0},
#  {'Close': 1.4672499895095825,
#   'Date': b'11/09/2007 00:00:00',
#   'High': 1.4751900434494019,
#   'Low': 1.4628599882125854,
#   'Open': 1.4676100015640259,
#   'Volume': 834383.0},
#  {'Close': 1.4655799865722656,
#   'Date': b'11/11/2007 00:00:00',
#   'High': 1.467579960823059,
#   'Low': 1.4632200002670288,
#   'Open': 1.4670100212097168,
#   'Volume': 21381.0},
#  {'Close': 1.4517799615859985,
#   'Date': b'11/12/2007 00:00:00',
#   'High': 1.4663200378417969,
#   'Low': 1.4516799449920654,
#   'Open': 1.465440034866333,
#   'Volume': 862041.0},
#  {'Close': 1.4618200063705444,
#   'Date': b'11/13/2007 00:00:00',
#   'High': 1.4632500410079956,
#   'Low': 1.4517199993133545,
#   'Open': 1.4521000385284424,
#   'Volume': 854543.0},
#  {'Close': 1.4649200439453125,
#   'Date': b'11/14/2007 00:00:00',
# ...
#  {'scaledClose': 0.26967654,
#   'scaledHigh': 0.26436105,
#   'scaledLow': 0.27898696,
#   'scaledOpen': 0.268683,
#   'scaledVolume': 0.0011292023},
#  {'scaledClose': 0.27248937,
#   'scaledHigh': 0.26706523,
#   'scaledLow': 0.27554873,
#   'scaledOpen': 0.2696503,
#   'scaledVolume': 0.026537934},
#  {'scaledClose': 0.280068,
#   'scaledHigh': 0.27359417,
#   'scaledLow': 0.27673674,
#   'scaledOpen': 0.27251709,
#   'scaledVolume': 0.03329603},
#  {'scaledClose': 0.2853355,
#   'scaledHigh': 0.27919802,
#   'scaledLow': 0.28993192,
#   'scaledOpen': 0.28011394,
#   'scaledVolume': 0.03157336},
#  {'scaledClose': 0.28282723,
#   'scaledHigh': 0.2802654,
#   'scaledLow': 0.29084995,
#   'scaledOpen': 0.28529194,
#   'scaledVolume': 0.029821146},
#  {'scaledClose': 0.28485176,
#   'scaledHigh': 0.28051457,
#   'scaledLow': 0.28982377,
#   'scaledOpen': 0.28281945,
#   'scaledVolume': 0.02554233},
#  {'scaledClose': 0.28277344,
#   'scaledHigh': 0.27740133,
#   'scaledLow': 0.29299203,
#   'scaledOpen': 0.28335685,
#   'scaledVolume': 0.0011181252},
#  {'scaledClose': 0.29594186,
#   'scaledHigh': 0.29001448,
#   'scaledLow': 0.28840166,
#   'scaledOpen': 0.2827477,
#   'scaledVolume': 0.03283851},
#  {'scaledClose': 0.29415035,
#   'scaledHigh': 0.29565394,
#   'scaledLow': 0.30280286,
#   'scaledOpen': 0.29593456,
#   'scaledVolume': 0.032619648},
#  {'scaledClose': 0.29501024,
#   'scaledHigh': 0.2892317,
#   'scaledLow': 0.29850045,
#   'scaledOpen': 0.29412502,
#   'scaledVolume': 0.028722491},
#  {'scaledClose': 0.29090738,
#   'scaledHigh': 0.29382163,
#   'scaledLow': 0.29761848,
#   'scaledOpen': 0.29500288,
#   'scaledVolume': 0.035844456},
#  {'scaledClose': 0.305151,
#   'scaledHigh': 0.29924756,
#   'scaledLow': 0.3010567,
#   'scaledOpen': 0.2909178,
#   'scaledVolume': 0.026966924},
#  {'scaledClose': 0.30432677,
#   'scaledHigh': 0.29892734,
#   'scaledLow': 0.31475577,
#   'scaledOpen': 0.30469608,
#   'scaledVolume': 0.0012859615},
#  {'scaledClose': 0.302553,
#   'scaledHigh': 0.30223632,
#   'scaledLow': 0.30971536,
#   'scaledOpen': 0.30433768,
#   'scaledVolume': 0.02685783},
#  {'scaledClose': 0.30432677,
#   'scaledHigh': 0.29796663,
#   'scaledLow': 0.3089774,
#   'scaledOpen': 0.30256385,
#   'scaledVolume': 0.027522126},
#  {'scaledClose': 0.3124966,
#   'scaledHigh': 0.30554512,
#   'scaledLow': 0.30885142,
#   'scaledOpen': 0.30428386,
#   'scaledVolume': 0.035204664},
#  {'scaledClose': 0.31065127,
#   'scaledHigh': 0.30812478,
#   'scaledLow': 0.31715,
#   'scaledOpen': 0.31252575,
#   'scaledVolume': 0.0332581},
#  {'scaledClose': 0.2913732,
#   'scaledHigh': 0.30397958,
#   'scaledLow': 0.30174083,
#   'scaledOpen': 0.3106086,
#   'scaledVolume': 0.03286536},
#  {'scaledClose': 0.2932008,
#   'scaledHigh': 0.2873103,
#   'scaledLow': 0.30318096,
#   'scaledOpen': 0.29387406,
#   'scaledVolume': 0.000894903},
#  {'scaledClose': 0.29888028,
#   'scaledHigh': 0.29499567,
#   'scaledLow': 0.30111077,
#   'scaledOpen': 0.2932113,
#   'scaledVolume': 0.027217336},
#  {'scaledClose': 0.29092532,
#   'scaledHigh': 0.29211357,
#   'scaledLow': 0.29857257,
#   'scaledOpen': 0.29890874,
#   'scaledVolume': 0.036322452},
#  {'scaledClose': 0.28967118,
#   'scaledHigh': 0.2861895,
#   'scaledLow': 0.2962324,
#   'scaledOpen': 0.29093575,
#   'scaledVolume': 0.027971592},
#  {'scaledClose': 0.30000883,
#   'scaledHigh': 0.2942129,
#   'scaledLow': 0.2974925,
#   'scaledOpen': 0.28969952,
#   'scaledVolume': 0.031765025},
#  {'scaledClose': 0.31728035,
#   'scaledHigh': 0.31194955,
#   'scaledLow': 0.30825743,
#   'scaledOpen': 0.30000168,
#   'scaledVolume': 0.043083567},
#  {'scaledClose': 0.31887472,
#   'scaledHigh': 0.31294587,
#   'scaledLow': 0.32757282,
#   'scaledOpen': 0.31702283,
#   'scaledVolume': 0.0019707333},
#  {'scaledClose': 0.31351796,
#   'scaledHigh': 0.31317726,
#   'scaledLow': 0.32165048,
#   'scaledOpen': 0.31886822,
#   'scaledVolume': 0.033242658},
#  {'scaledClose': 0.31414503,
#   'scaledHigh': 0.31376427,
#   'scaledLow': 0.32091227,
#   'scaledOpen': 0.31352898,
#   'scaledVolume': 0.035126116},
#  {'scaledClose': 0.3022664,
#   'scaledHigh': 0.3085161,
#   'scaledLow': 0.3105615,
#   'scaledOpen': 0.3141561,
#   'scaledVolume': 0.055203024},
#  {'scaledClose': 0.3020872,
#   'scaledHigh': 0.30033275,
#   'scaledLow': 0.3080233,
#   'scaledOpen': 0.30224133,
#   'scaledVolume': 0.041568678},
#  {'scaledClose': 0.31378663,
#   'scaledHigh': 0.30775112,
#   'scaledLow': 0.3115156,
#   'scaledOpen': 0.30209804,
#   'scaledVolume': 0.032740828},
#  {'scaledClose': 0.3151841,
#   'scaledHigh': 0.30835596,
#   'scaledLow': 0.32339662,
#   'scaledOpen': 0.31431735,
#   'scaledVolume': 0.00093988306},
#  {'scaledClose': 0.31634873,
#   'scaledHigh': 0.31148702,
#   'scaledLow': 0.32143438,
#   'scaledOpen': 0.3151595,
#   'scaledVolume': 0.027241504},
#  {'scaledClose': 0.32817334,
#   'scaledHigh': 0.32308623,
#   'scaledLow': 0.32638484,
#   'scaledOpen': 0.31630626,
#   'scaledVolume': 0.03191071},
#  {'scaledClose': 0.31887472,
#   'scaledHigh': 0.32507867,
#   'scaledLow': 0.327537,
#   'scaledOpen': 0.32820305,
#   'scaledVolume': 0.040968496},
#  {'scaledClose': 0.32863915,
#   'scaledHigh': 0.32239255,
#   'scaledLow': 0.329175,
#   'scaledOpen': 0.31886822,
#   'scaledVolume': 0.03065328},
#  {'scaledClose': 0.32020062,
#   'scaledHigh': 0.32410038,
#   'scaledLow': 0.327699,
#   'scaledOpen': 0.32865095,
#   'scaledVolume': 0.03203726},
#  {'scaledClose': 0.32068437,
#   'scaledHigh': 0.31426245,
#   'scaledLow': 0.329769,
#   'scaledOpen': 0.32019418,
#   'scaledVolume': 0.0016028363},
#  {'scaledClose': 0.32668638,
#   'scaledHigh': 0.3223569,
#   'scaledLow': 0.33025506,
#   'scaledOpen': 0.32067794,
#   'scaledVolume': 0.026813185},
#  {'scaledClose': 0.3325628,
#   'scaledHigh': 0.32886803,
#   'scaledLow': 0.3368077,
#   'scaledOpen': 0.32668018,
#   'scaledVolume': 0.03246054},
#  {'scaledClose': 0.3227448,
#   'scaledHigh': 0.32824537,
#   'scaledLow': 0.33153316,
#   'scaledOpen': 0.3325568,
#   'scaledVolume': 0.030548213},
#  {'scaledClose': 0.32287017,
#   'scaledHigh': 0.3197062,
#   'scaledLow': 0.3302911,
#   'scaledOpen': 0.3227384,
#   'scaledVolume': 0.028898383},
#  {'scaledClose': 0.3224761,
#   'scaledHigh': 0.31790927,
#   'scaledLow': 0.32262257,
#   'scaledOpen': 0.3228638,
#   'scaledVolume': 0.032200057},
#  {'scaledClose': 0.3222431,
#   'scaledHigh': 0.31701985,
#   'scaledLow': 0.33279327,
#   'scaledOpen': 0.3239926,
#   'scaledVolume': 0.00090463745},
#  {'scaledClose': 0.33000094,
#   'scaledHigh': 0.3231575,
#   'scaledLow': 0.33174926,
#   'scaledOpen': 0.32225466,
#   'scaledVolume': 0.019665038},
#  {'scaledClose': 0.3272955,
#   'scaledHigh': 0.32669765,
#   'scaledLow': 0.3367536,
#   'scaledOpen': 0.32999483,
#   'scaledVolume': 0.027440893},
#  {'scaledClose': 0.3258622,
#   'scaledHigh': 0.3217699,
#   'scaledLow': 0.32829303,
#   'scaledOpen': 0.32725343,
#   'scaledVolume': 0.026115993},
#  {'scaledClose': 0.31163675,
#   'scaledHigh': 0.3195639,
#   'scaledLow': 0.32003027,
#   'scaledOpen': 0.32585594,
#   'scaledVolume': 0.032789163},
#  {'scaledClose': 0.31779978,
#   'scaledHigh': 0.3144936,
#   'scaledLow': 0.31747404,
#   'scaledOpen': 0.31161204,
#   'scaledVolume': 0.030722093},
#  {'scaledClose': 0.31819406,
#   'scaledHigh': 0.3112915,
#   'scaledLow': 0.32750094,
#   'scaledOpen': 0.31702283,
#   'scaledVolume': 0.0007854737},
#  {'scaledClose': 0.3224761,
#   'scaledHigh': 0.3173579,
#   'scaledLow': 0.32483676,
#   'scaledOpen': 0.3181696,
#   'scaledVolume': 0.019060493},
#  {'scaledClose': 0.31923312,
#   'scaledHigh': 0.3160057,
#   'scaledLow': 0.32832906,
#   'scaledOpen': 0.32246974,
#   'scaledVolume': 0.025562134},
#  {'scaledClose': 0.32030806,
#   'scaledHigh': 0.32023978,
#   'scaledLow': 0.329625,
#   'scaledOpen': 0.31924456,
#   'scaledVolume': 0.017970564},
#  {'scaledClose': 0.31925106,
#   'scaledHigh': 0.31607696,
#   'scaledLow': 0.32456657,
#   'scaledOpen': 0.32026595,
#   'scaledVolume': 0.03852849},
#  {'scaledClose': 0.30755162,
#   'scaledHigh': 0.31579235,
#   'scaledLow': 0.31542185,
#   'scaledOpen': 0.3192625,
#   'scaledVolume': 0.025587982},
#  {'scaledClose': 0.30796382,
#   'scaledHigh': 0.30141792,
#   'scaledLow': 0.31725815,
#   'scaledOpen': 0.30706114,
#   'scaledVolume': 0.0010395778},
#  {'scaledClose': 0.31016752,
#   'scaledHigh': 0.3046913,
#   'scaledLow': 0.31572786,
#   'scaledOpen': 0.30797487,
#   'scaledVolume': 0.01913434},
#  {'scaledClose': 0.31065127,
#   'scaledHigh': 0.30768007,
#   'scaledLow': 0.317006,
#   'scaledOpen': 0.31016073,
#   'scaledVolume': 0.023416515},
#  {'scaledClose': 0.28744954,
#   'scaledHigh': 0.30543843,
#   'scaledLow': 0.29634035,
#   'scaledOpen': 0.31066242,
#   'scaledVolume': 0.040435784},
#  {'scaledClose': 0.27275828,
#   'scaledHigh': 0.2825783,
#   'scaledLow': 0.27925694,
#   'scaledOpen': 0.28742397,
#   'scaledVolume': 0.04618317},
#  {'scaledClose': 0.26311922,
#   'scaledHigh': 0.26811478,
#   'scaledLow': 0.27126437,
#   'scaledOpen': 0.27273217,
#   'scaledVolume': 0.046165712},
#  {'scaledClose': 0.26514372,
#   'scaledHigh': 0.25930882,
#   'scaledLow': 0.27252448,
#   'scaledOpen': 0.26221493,
#   'scaledVolume': 0.0022362503},
#  {'scaledClose': 0.27256113,
#   'scaledHigh': 0.26747432,
#   'scaledLow': 0.27133626,
#   'scaledOpen': 0.26509944,
#   'scaledVolume': 0.03758626},
#  {'scaledClose': 0.2769506,
#   'scaledHigh': 0.27304277,
#   'scaledLow': 0.2773127,
#   'scaledOpen': 0.27255297,
#   'scaledVolume': 0.030346474},
#  {'scaledClose': 0.27573234,
#   'scaledHigh': 0.27613822,
#   'scaledLow': 0.28280333,
#   'scaledOpen': 0.2769426,
#   'scaledVolume': 0.030004425},
#  {'scaledClose': 0.27540985,
#   'scaledHigh': 0.273683,
#   'scaledLow': 0.28393722,
#   'scaledOpen': 0.27574223,
#   'scaledVolume': 0.027454656},
#  {'scaledClose': 0.27664605,
#   'scaledHigh': 0.27704546,
#   'scaledLow': 0.2854675,
#   'scaledOpen': 0.2754018,
#   'scaledVolume': 0.024612851},
#  {'scaledClose': 0.27784637,
#   'scaledHigh': 0.27113917,
#   'scaledLow': 0.28609756,
#   'scaledOpen': 0.2757243,
#   'scaledVolume': 0.0009969474},
#  {'scaledClose': 0.27555317,
#   'scaledHigh': 0.2715839,
#   'scaledLow': 0.2811651,
#   'scaledOpen': 0.27785632,
#   'scaledVolume': 0.02786082},
#  {'scaledClose': 0.27046484,
#   'scaledHigh': 0.26893318,
#   'scaledLow': 0.2767187,
#   'scaledOpen': 0.27556306,
#   'scaledVolume': 0.02937638},
#  {'scaledClose': 0.2625101,
#   'scaledHigh': 0.26528612,
#   'scaledLow': 0.2708682,
#   'scaledOpen': 0.27047455,
#   'scaledVolume': 0.032971434},
#  {'scaledClose': 0.26070043,
#   'scaledHigh': 0.26087433,
#   'scaledLow': 0.26948217,
#   'scaledOpen': 0.2625195,
#   'scaledVolume': 0.03286536},
#  {'scaledClose': 0.2636568,
#   'scaledHigh': 0.25907743,
#   'scaledLow': 0.2640276,
#   'scaledOpen': 0.26065618,
#   'scaledVolume': 0.03132026},
#  {'scaledClose': 0.2624742,
#   'scaledHigh': 0.2580811,
#   'scaledLow': 0.27275836,
#   'scaledOpen': 0.26321813,
#   'scaledVolume': 0.0016756773},
#  {'scaledClose': 0.26369247,
#   'scaledHigh': 0.26019824,
#   'scaledLow': 0.27200234,
#   'scaledOpen': 0.2624657,
#   'scaledVolume': 0.020123232},
#  {'scaledClose': 0.2564722,
#   'scaledHigh': 0.26281333,
#   'scaledLow': 0.26399177,
#   'scaledOpen': 0.26366603,
#   'scaledVolume': 0.032921754},
#  {'scaledClose': 0.2512408,
#   'scaledHigh': 0.25237057,
#   'scaledLow': 0.25943744,
#   'scaledOpen': 0.2564814,
#   'scaledVolume': 0.033003323},
#  {'scaledClose': 0.26080808,
#   'scaledHigh': 0.25795662,
#   'scaledLow': 0.25977927,
#   'scaledOpen': 0.2512139,
#   'scaledVolume': 0.04606535},
#  {'scaledClose': 0.26523343,
#   'scaledHigh': 0.26030493,
#   'scaledLow': 0.26724994,
#   'scaledOpen': 0.2607995,
#   'scaledVolume': 0.031969786},
#  {'scaledClose': 0.2654483,
#   'scaledHigh': 0.25955778,
#   'scaledLow': 0.27446848,
#   'scaledOpen': 0.26595953,
#   'scaledVolume': 0.0014252656},
#  {'scaledClose': 0.2637463,
#   'scaledHigh': 0.26016262,
#   'scaledLow': 0.26924804,
#   'scaledOpen': 0.26543987,
#   'scaledVolume': 0.02550977},
#  {'scaledClose': 0.2479978,
#   'scaledHigh': 0.25925535,
#   'scaledLow': 0.25774515,
#   'scaledOpen': 0.2637378,
#   'scaledVolume': 0.031070184},
#  {'scaledClose': 0.25840724,
#   'scaledHigh': 0.25277966,
#   'scaledLow': 0.25767323,
#   'scaledOpen': 0.24797082,
#   'scaledVolume': 0.026943091},
#  {'scaledClose': 0.25451943,
#   'scaledHigh': 0.2548968,
#   'scaledLow': 0.2620836,
#   'scaledOpen': 0.25839856,
#   'scaledVolume': 0.026797408},
#  {'scaledClose': 0.2533548,
#   'scaledHigh': 0.24982652,
#   'scaledLow': 0.2613454,
#   'scaledOpen': 0.2545463,
#   'scaledVolume': 0.023964332},
#  {'scaledClose': 0.25475225,
#   'scaledHigh': 0.24835005,
#   'scaledLow': 0.26336172,
#   'scaledOpen': 0.25347131,
#   'scaledVolume': 0.000842538},
#  {'scaledClose': 0.2510257,
#   'scaledHigh': 0.25023583,
#   'scaledLow': 0.25621507,
#   'scaledOpen': 0.25474346,
#   'scaledVolume': 0.03486261},
#  {'scaledClose': 0.24916245,
#   'scaledHigh': 0.24632199,
#   'scaledLow': 0.2547569,
#   'scaledOpen': 0.25101677,
#   'scaledVolume': 0.034986477},
#  {'scaledClose': 0.2511152,
#   'scaledHigh': 0.24671327,
#   'scaledLow': 0.25409082,
#   'scaledOpen': 0.24911757,
#   'scaledVolume': 0.026255298},
#  {'scaledClose': 0.24753198,
#   'scaledHigh': 0.2513032,
#   'scaledLow': 0.25506294,
#   'scaledOpen': 0.2511601,
#   'scaledVolume': 0.038915522},
#  {'scaledClose': 0.24683337,
#   'scaledHigh': 0.24349333,
#   'scaledLow': 0.25455883,
#   'scaledOpen': 0.24752292,
#   'scaledVolume': 0.02219064},
#  {'scaledClose': 0.24763942,
#   'scaledHigh': 0.24132296,
#   'scaledLow': 0.25684512,
#   'scaledOpen': 0.2467884,
#   'scaledVolume': 0.00060790294},
#  {'scaledClose': 0.2533548,
#   'scaledHigh': 0.24895489,
#   'scaledLow': 0.25614297,
#   'scaledOpen': 0.2476483,
#   'scaledVolume': 0.02509857},
#  {'scaledClose': 0.2561497,
#   'scaledHigh': 0.25317115,
#   'scaledLow': 0.2573312,
#   'scaledOpen': 0.253328,
#   'scaledVolume': 0.023536686},
#  {'scaledClose': 0.26064682,
#   'scaledHigh': 0.25468326,
#   'scaledLow': 0.25774515,
#   'scaledOpen': 0.25617683,
#   'scaledVolume': 0.03210305},
#  {'scaledClose': 0.26869127,
#   'scaledHigh': 0.26265323,
#   'scaledLow': 0.27007616,
#   'scaledOpen': 0.2606203,
#   'scaledVolume': 0.021846239},
#  {'scaledClose': 0.26446283,
#   'scaledHigh': 0.26519728,
#   'scaledLow': 0.2720384,
#   'scaledOpen': 0.26866505,
#   'scaledVolume': 0.026315048},
#  {'scaledClose': 0.26435542,
#   'scaledHigh': 0.25824124,
#   'scaledLow': 0.27394658,
#   'scaledOpen': 0.26398855,
#   'scaledVolume': 0.0005538597},
#  {'scaledClose': 0.2657708,
#   'scaledHigh': 0.26311576,
#   'scaledLow': 0.27333456,
#   'scaledOpen': 0.2643649,
#   'scaledVolume': 0.02207584},
#  {'scaledClose': 0.2649466,
#   'scaledHigh': 0.26247528,
#   'scaledLow': 0.2723983,
#   'scaledOpen': 0.2657265,
#   'scaledVolume': 0.02036995},
#  {'scaledClose': 0.25915965,
#   'scaledHigh': 0.2636139,
#   'scaledLow': 0.26863602,
#   'scaledOpen': 0.26492023,
#   'scaledVolume': 0.01989229},
#  {'scaledClose': 0.25846106,
#   'scaledHigh': 0.25607085,
#   'scaledLow': 0.2678081,
#   'scaledOpen': 0.25918692,
#   'scaledVolume': 0.017734922},
#  {'scaledClose': 0.24527445,
#   'scaledHigh': 0.25181916,
#   'scaledLow': 0.25454104,
#   'scaledOpen': 0.2584524,
#   'scaledVolume': 0.018509319},
#  {'scaledClose': 0.24308868,
#   'scaledHigh': 0.23895685,
#   'scaledLow': 0.25236267,
#   'scaledOpen': 0.24497868,
#   'scaledVolume': 0.0020744563},
#  {'scaledClose': 0.24104622,
#   'scaledHigh': 0.24036227,
#   'scaledLow': 0.2509586,
#   'scaledOpen': 0.24313329,
#   'scaledVolume': 0.016292537},
#  {'scaledClose': 0.23809007,
#   'scaledHigh': 0.2357013,
#   'scaledLow': 0.24647637,
#   'scaledOpen': 0.241019,
#   'scaledVolume': 0.025317093},
#  {'scaledClose': 0.24206756,
#   'scaledHigh': 0.23772936,
#   'scaledLow': 0.24582829,
#   'scaledOpen': 0.23808068,
#   'scaledVolume': 0.020496164},
#  {'scaledClose': 0.24097468,
#   'scaledHigh': 0.23666199,
#   'scaledLow': 0.24901436,
#   'scaledOpen': 0.24202242,
#   'scaledVolume': 0.01534527},
#  {'scaledClose': 0.25131235,
#   'scaledHigh': 0.24669546,
#   'scaledLow': 0.25020257,
#   'scaledOpen': 0.24098332,
#   'scaledVolume': 0.014377525},
#  {'scaledClose': 0.25143772,
#   'scaledHigh': 0.24601957,
#   'scaledLow': 0.26123744,
#   'scaledOpen': 0.25132135,
#   'scaledVolume': 0.0009405544},
#  {'scaledClose': 0.2484995,
#   'scaledHigh': 0.24600175,
#   'scaledLow': 0.25686315,
#   'scaledOpen': 0.25141084,
#   'scaledVolume': 0.014673253},
#  {'scaledClose': 0.23622681,
#   'scaledHigh': 0.24315529,
#   'scaledLow': 0.24507205,
#   'scaledOpen': 0.24849047,
#   'scaledVolume': 0.01992015},
#  {'scaledClose': 0.23852001,
#   'scaledHigh': 0.23333517,
#   'scaledLow': 0.24582829,
#   'scaledOpen': 0.23623528,
#   'scaledVolume': 0.008024923}]
